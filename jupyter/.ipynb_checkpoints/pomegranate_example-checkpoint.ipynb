# %% [markdown]
# # Pomegranate example

# %%
import numpy

import matplotlib.pyplot as plt

from sklearn.datasets import make_blobs
from sklearn.metrics import confusion_matrix
from plot_utilities_svm import plot_confusion_matrix
from sklearn.model_selection import train_test_split
from pomegranate import NaiveBayes, NormalDistribution

n, d, m = 50000, 5, 10
std_noise = 10
X, y = make_blobs(n, d, m, cluster_std=std_noise)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)

n_unlabeled = int(X_train.shape[0] * 0.999)
idxs = numpy.random.choice(X_train.shape[0], size=n_unlabeled)
y_train[idxs] = -1

model = NaiveBayes.from_samples(NormalDistribution, X_train, y_train, verbose=True)
# Out:
# [1] Improvement: 34.29249055986293	Time (s): 0.04161
# [2] Improvement: 4.83358434739057	Time (s): 0.04096
# [3] Improvement: 1.7514894173946232	Time (s): 0.04336
# [4] Improvement: 0.7378557448973879	Time (s): 0.04523
# [5] Improvement: 0.34058989956974983	Time (s): 0.044
# [6] Improvement: 0.16712912009097636	Time (s): 0.04818
# [7] Improvement: 0.08558805263601243	Time (s): 0.04291
# Total Improvement: 42.208727141842246
# Total Time (s): 0.3603

# %%
class_names = numpy.arange(m)
y_pred = model.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
plot_confusion_matrix(plt, numpy, cm, class_names)
# Out:
# Normalized confusion matrix
# [[0.46025105 0.03556485 0.06903766 0.0041841  0.04393305 0.06485356
#   0.07740586 0.0041841  0.16736402 0.07322176]
#  [0.0480167  0.33820459 0.05219207 0.0605428  0.04592902 0.07098121
#   0.02296451 0.05636743 0.15240084 0.15240084]
#  [0.05675147 0.05479452 0.33855186 0.11350294 0.04500978 0.05283757
#   0.0665362  0.17612524 0.06262231 0.0332681 ]
#  [0.00614754 0.07172131 0.06352459 0.48360656 0.06147541 0.01229508
#   0.09221311 0.13114754 0.05327869 0.02459016]
#  [0.08333333 0.06300813 0.06504065 0.06707317 0.24796748 0.14430894
#   0.12804878 0.07520325 0.07723577 0.04878049]
#  [0.0662768  0.04483431 0.06237817 0.03118908 0.11890838 0.39181287
#   0.09746589 0.11695906 0.02534113 0.04483431]
#  [0.06570842 0.02669405 0.06776181 0.07597536 0.08213552 0.09445585
#   0.44558522 0.04106776 0.01848049 0.08213552]
#  [0.0185567  0.09896907 0.14020619 0.17938144 0.05154639 0.08865979
#   0.05154639 0.32989691 0.02268041 0.0185567 ]
#  [0.12138728 0.0867052  0.04046243 0.04816956 0.05202312 0.01926782
#   0.01156069 0.00192678 0.54527938 0.07321773]
#  [0.09306569 0.14963504 0.02554745 0.02372263 0.03467153 0.05839416
#   0.09671533 0.02007299 0.07664234 0.42153285]]
# Accuracy =  0.401
